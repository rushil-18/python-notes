# %% [markdown]
# application programming interface - API
# -> api helps two softwares communicate with eachother
# -> apis are data pipelines which help in communicate with point a to point b

# %%
import pandas as pd 
import requests

requests.get('url')

# %%
# Out:
# {"message":"You are not subscribed to this API."}
