# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# c:\Users\Samatha Moota\Videos\python-notes\.venv\Scripts\python.exe

# %% [markdown]
# installaion -
# python -m pip install fg-data-profiling
# from data_profiling import ProfileReport
# profile = ProfileRepot(df , title = "Data Proffiling Report)
# profile
#
# profile.to_file("eda.html")

# %%
from data_profiling import ProfileReport

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
print("Everything works!")
# Out:
# Everything works!

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %% [markdown]
# creates a report right here

# %%
profile = ProfileReport(df, title = "Data processing Report")
profile

# %% [markdown]
# creates a html page for eda

# %%
profile = ProfileReport(df, title = "Data processing Report")
profile.to_file("eda.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
