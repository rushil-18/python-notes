# %% [markdown]
# analyzing a single variable from a data with multiple variables is uni
# bi is 2 varibales
# more is multi variable analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 668          669         0       3
# 600          601         1       2
# 14            15         0       3
# 187          188         1       1
# 787          788         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 668                                    Cook, Mr. Jacob    male  43.0      0
# 600  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0      2
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 187      Romaine, Mr. Charles Hallace ("Mr C Rolmane")    male  45.0      0
# 787                          Rice, Master. George Hugh    male   8.0      4
#
#      Parch    Ticket     Fare Cabin Embarked
# 668      0  A/5 3536   8.0500   NaN        S
# 600      1    243847  27.0000   NaN        S
# 14       0    350406   7.8542   NaN        S
# 187      0    111428  26.5500   NaN        S
# 787      1    382652  29.1250   NaN        Q

# %% [markdown]
# categorical data

# %%
sns.countplot(data = df, x = 'Survived', hue = 'Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Pclass' , hue = 'Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.countplot(data = df, x = 'Sex' , hue = 'Sex', )
plt.subplot(2,2,2)
sns.countplot(data = df, x = 'Embarked' , hue = "Embarked")
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# pie chart

# %%
df["Survived"].value_counts().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: >

# %%
sns.histplot(data = df, x = 'Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.distplot(df["Age"])
# Out:
# C:\Users\Samatha Moota\AppData\Local\Temp\ipykernel_11552\2732350774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(data = df , x = "Age")
# Out:
# <Axes: xlabel='Age'>
