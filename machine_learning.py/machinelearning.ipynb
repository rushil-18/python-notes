# %%
# %pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\samatha moota\appdata\local\programs\python\python313\lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\samatha moota\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\samatha moota\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\samatha moota\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\samatha moota\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\samatha moota\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
a = np.array(1)
b = np.array([1,2,3,4])
c= np.array([
    [1,2,3,4],
    [6,7,8,9],
    [10,11,12,13]
])
print(a)
print(b)
print(c)
# Out:
# 1
# [1 2 3 4]
# [[ 1  2  3  4]
#  [ 6  7  8  9]
#  [10 11 12 13]]

# %%
df = pd.read_csv('placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df = df.iloc[:,1:]

# %%
plt.scatter(df['cgpa'] , df['iq'] , c=df['placement'], label = "placement")
plt.legend()

# %% [markdown]
# feature selection

# %%
X = df.iloc[: , 0:2]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.1)

# %% [markdown]
# standardization - converting into 0s and 1s

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()

X_train = scalar.fit_transform(X_train)
X_test = scalar.fit_transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train , Y_train)
# Out:
# LogisticRegression()

# %%
pred = clf.predict(X_test)
pred
# Out:
# array([1, 1, 1, 0, 0, 1, 0, 1, 0, 0])

# %%
Y_test
# Out:
# 61    1
# 83    1
# 79    1
# 81    0
# 9     0
# 65    1
# 95    0
# 43    1
# 24    0
# 31    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test ,pred)
# Out:
# 1.0

# %% [markdown]
# exporting the model

# %%
import pickle
pickle.dump(clf, open('model.pkl' , 'wb'))

# %% [markdown]
# decision boundary
